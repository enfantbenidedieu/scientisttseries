# %%
import os
os.chdir("D:/Bureau/PythonProject/packages/scientisttseries/data")

# Chargement des données
import pandas as pd
import numpy as np

df = pd.read_excel("c5ex2.xls",header=0,index_col=0)
df.index = pd.date_range(start="2000-01-31",periods=len(df),freq="M")
df.head()
# Out:
#                 TOTPHAR    TOTPHARSA
# 2000-01-31  1766.329705  1628.372370
# 2000-02-29  1799.817447  1793.320963
# 2000-03-31  2022.353306  1847.212570
# 2000-04-30  1762.868650  1845.445843
# 2000-05-31  1883.066309  1945.822600

# %% [markdown]
# ### Z -tau
#
# #### Modèle constant
#
# ##### lags = "short"

# %%
from scientisttseries.uniroot import PP,summaryPP

pp1 = PP(df.TOTPHARSA,typ="Z-tau",model="constant",lags="short",use_lag=None)
summaryPP(pp1)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ##### Lags == "long"

# %%
pp2 = PP(df.TOTPHARSA,typ="Z-tau",model="constant",lags="long",use_lag=None)
summaryPP(pp2)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# #### Modèle trend
#
# ##### lags == "short"

# %%
# 
pp3 = PP(df.TOTPHARSA,typ="Z-tau",model="trend",lags="short",use_lag=None)
summaryPP(pp3)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
pp4 = PP(df.TOTPHARSA,typ="Z-tau",model="trend",lags="long",use_lag=None)
summaryPP(pp4)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
pp5 = PP(df.TOTPHARSA,typ="Z-tau",model="constant",lags="long",use_lag=3)
summaryPP(pp5)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
pp6 = PP(df.TOTPHARSA,typ="Z-tau",model="trend",lags="long",use_lag=3)
summaryPP(pp6)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## Z - alpha
#
# ### Model - constant
#
# #### lags = "short"

# %%
pp7 = PP(df.TOTPHARSA,typ="Z-alpha",model="constant",lags="short",use_lag=None)
summaryPP(pp7)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
pp8 = PP(df.TOTPHARSA,typ="Z-alpha",model="constant",lags="long",use_lag=None)
summaryPP(pp8)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
pp9 = PP(df.TOTPHARSA,typ="Z-alpha",model="trend",lags="short",use_lag=None)
summaryPP(pp9)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
pp10 = PP(df.TOTPHARSA,typ="Z-alpha",model="trend",lags="long",use_lag=None)
summaryPP(pp10)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
pp11 = PP(df.TOTPHARSA,typ="Z-alpha",model="constant",lags="long",use_lag=3)
summaryPP(pp11)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     3722.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          3.99e-115
# Time:                        22:45:48   Log-Likelihood:                -1181.2
# No. Observations:                 167   AIC:                             2366.
# Df Residuals:                     165   BIC:                             2373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
pp12 = PP(df.TOTPHARSA,typ="Z-alpha",model="trend",lags="long",use_lag=3)
summaryPP(pp12)
# Out:
# ################################################################################
# #                        Phillips - Perron Unit Root Test                      #
# ################################################################################
# Model with intercept and trend
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     4078.
# Date:                Sun, 03 Sep 2023   Prob (F-statistic):          1.47e-140
# Time:                        22:45:48   Log-Likelihood:                -1117.1
# No. Observations:                 167   AIC:                             2240.
# Df Residuals:                     164   BIC:                             2250.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
